# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
path="/content/drive/MyDrive/UGATIT_without_g"
os.chdir(path)
os.listdir(path)
# Out:
# ['main.py',
#  'utils.py',
#  'dataset.py',
#  '__pycache__',
#  'networks.py',
#  'results',
#  'Untitled0.ipynb',
#  'dataset',
#  'UGATIT.py']

# %%
# !python main.py --dataset cat2dog --light True --iteration 50000 --save_freq 1000 --resume True
#15h+
# Out:
# number of epochs must be larger than or equal to one
#
# ##### Information #####
# # light :  True
# # dataset :  cat2dog
# # batch_size :  1
# # iteration per epoch :  50000
#
# ##### Generator #####
# # residual blocks :  4
#
# ##### Discriminator #####
# # discriminator layer :  6
#
# ##### Weight #####
# # adv_weight :  1
# # cycle_weight :  10
# # identity_weight :  10
# # cam_weight :  1000
#  [*] Load SUCCESS
# training start !
# [47000/50000] time: 1.5535 d_loss: 2.33979702, g_loss: 103.04774475
# [47001/50000] time: 30.2142 d_loss: 2.69893360, g_loss: 56.25003815
# [47002/50000] time: 31.5820 d_loss: 3.17929077, g_loss: 77.90972137
# [47003/50000] time: 32.9089 d_loss: 2.54481125, g_loss: 317.68585205
# [47004/50000] time: 34.1682 d_loss: 4.44779730, g_loss: 265.65679932
# [47005/50000] time: 35.4940 d_loss: 1.86709559, g_loss: 172.12629700
# [47006/50000] time: 36.9674 d_loss: 2.42082214, g_loss: 567.89331055
# ...

# %%
# !python main.py --dataset cat2dog --phase test --light True
# Out:
# number of epochs must be larger than or equal to one
#
# ##### Information #####
# # light :  True
# # dataset :  cat2dog
# # batch_size :  1
# # iteration per epoch :  1000000
#
# ##### Generator #####
# # residual blocks :  4
#
# ##### Discriminator #####
# # discriminator layer :  6
#
# ##### Weight #####
# # adv_weight :  1
# # cycle_weight :  10
# # identity_weight :  10
# # cam_weight :  1000
#  [*] Load SUCCESS
#  [*] Test finished!

# %%
pip install pytorch-fid
# Out:
# ...
#   Created wheel for pytorch-fid: filename=pytorch_fid-0.2.0-cp37-none-any.whl size=10547 sha256=a326b27b85fda6c02d71626cf1db2693cfbb934f1aac64e34b7c92bbdd7f5466
#   Stored in directory: /root/.cache/pip/wheels/72/36/3c/4f3fb256f62d24bef52636f66f21667bc21caa637ce92f0e53
# Successfully built pytorch-fid
# ...

# %%
# !python -m pytorch_fid "./results/cat2dog/realB" "./results/cat2dog/fakeB"
# Out:
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:04<00:00, 23.2MB/s]
# 100% 2/2 [00:00<00:00,  2.69it/s]
# 100% 2/2 [00:00<00:00,  2.73it/s]
# FID:  223.20580774484048

# %%
# !python -m pytorch_fid "./results/cat2dog/realA" "./results/cat2dog/fakeA"
# Out:
# 100% 2/2 [00:00<00:00,  2.67it/s]
# 100% 2/2 [00:00<00:00,  2.69it/s]
# FID:  210.01472296506046
